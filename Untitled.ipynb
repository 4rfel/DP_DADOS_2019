# %%
with open("input PES2015.txt", "r") as txt:
    conversor = txt.readlines()

# %%
conversor[0]
# Out:
# '@00001\t\t\tV0101          $4.          /*Ano de referência*/\n'

# %%
import pandas as pd

# %%
PES2015 = pd.read_csv('PES2015.csv',sep=',')

# %%
PES2015.drop('Unnamed: 0', axis=1, inplace=True)

# %%
old_columns = (PES2015.columns)

# %%
def clean_conversor_line(line, og_codes):
    new_name = ""
    first = False
    code = ""
    counter = 0
    
    for e in line:
        if e == "V":
            counter = 5
            
        if counter > 0:
            code += e
            counter -= 1
        if code in og_codes:
            if e == "/" and not first:
                first = True
            elif e != '/' and first:
                new_name += e
    
    new_name = new_name.replace("*","")
    new_name = new_name.replace("\n", "")
    
    return new_name, code


# aa = "'@00001\t\t\tV6002          $4.          /*aa*/\n'"
# clean_conversor_line(aa,old_columns)
new_columns = []
code = []
for e in conversor:
    new, c = (clean_conversor_line(e, old_columns))
    if new != "":
        new_columns.append(new)
        code.append(c)

# %%
code
# Out:
# ['V0101',
#  'V0102',
#  'V0103',
#  'V0301',
#  'V0302',
#  'V3031',
#  'V3032',
#  'V3033',
#  'V8005',
#  'V0401',
#  'V0402',
#  'V0403',
#  'V0404',
#  'V0405',
#  'V0406',
#  'V0407',
#  'V0408',
#  'V4112',
#  'V4011',
#  'V0412',
#  'V0501',
#  'V0502',
#  'V5030',
#  'V0504',
#  'V0505',
#  'V5061',
#  'V5062',
#  'V5063',
#  'V5064',
#  'V5065',
#  'V0507',
#  'V5080',
#  'V5090',
#  'V0510',
#  'V0511',
#  'V5121',
#  'V5122',
#  'V5123',
#  'V5124',
#  'V5125',
#  'V5126',
#  'V0601',
#  'V0602',
#  'V6002',
#  'V6020',
#  'V6003',
#  'V6030',
#  'V0604',
#  'V0605',
#  'V0606',
#  'V6007',
#  'V6070',
#  'V0608',
#  'V0609',
#  'V0610',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0611',
#  'V0612',
#  'V0701',
#  'V0702',
#  'V0703',
#  'V0704',
#  'V0705',
#  'V7060',
#  'V7070',
#  'V0708',
#  'V7090',
#  'V7100',
#  'V0711',
#  'V7121',
#  'V7122',
#  'V7124',
#  'V7125',
#  'V7127',
#  'V7128',
#  'V0713',
#  'V0714',
#  'V0715',
#  'V0716',
#  'V9001',
#  'V9002',
#  'V9003',
#  'V9004',
#  'V9005',
#  'V9906',
#  'V9907',
#  'V9008',
#  'V9009',
#  'V9010',
#  'V9010',
#  'V9011',
#  'V9012',
#  'V9012',
#  'V9013',
#  'V9014',
#  'V9151',
#  'V9152',
#  'V9154V9152',
#  'V9156',
#  'V9157',
#  'V9159V9157',
#  'V9161',
#  'V9162',
#  'V9164V9162',
#  'V9016',
#  'V9017',
#  'V9018',
#  'V9019',
#  'V9201',
#  'V9202',
#  'V9204V9202',
#  'V9206',
#  'V9207',
#  'V9209V9207',
#  'V9211',
#  'V9212',
#  'V9214V9212',
#  'V9021',
#  'V9022',
#  'V9023',
#  'V9024',
#  'V9026',
#  'V9027',
#  'V9028',
#  'V9029',
#  'V9030',
#  'V9031',
#  'V9032',
#  'V9033',
#  'V9034',
#  'V9035',
#  'V9036',
#  'V9037',
#  'V9038',
#  'V9039',
#  'V9040',
#  'V9041',
#  'V9042',
#  'V9043',
#  'V9044',
#  'V9045',
#  'V9046',
#  'V9047',
#  'V9048',
#  'V9049',
#  'V9050',
#  'V9051',
#  'V9052',
#  'V9531',
#  'V9532',
#  'V9534',
#  'V9535',
#  'V9537',
#  'V9054',
#  'V9055',
#  'V9056',
#  'V9057',
#  'V9058',
#  'V9059',
#  'V9060',
#  'V9611',
#  'V9612',
#  'V9062',
#  'V9063',
#  'V9064',
#  'V9065',
#  'V9066',
#  'V9067',
#  'V9068',
#  'V9069',
#  'V9070',
#  'V9971',
#  'V9972',
#  'V9073',
#  'V9074',
#  'V9075',
#  'V9076',
#  'V9077',
#  'V9078',
#  'V9079',
#  'V9080',
#  'V9081',
#  'V9082',
#  'V9083',
#  'V9084',
#  'V9085',
#  'V9861',
#  'V9862',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9087',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9088',
#  'V9891',
#  'V9892',
#  'V9990',
#  'V9991',
#  'V9092',
#  'V9093',
#  'V9094',
#  'V9095',
#  'V9096',
#  'V9097',
#  'V9981',
#  'V9982',
#  'V9984',
#  'V9985',
#  'V9987',
#  'V9099',
#  'V9100',
#  'V9101',
#  'V1021',
#  'V1022',
#  'V1024',
#  'V1025',
#  'V1027',
#  'V1028',
#  'V9103',
#  'V9104',
#  'V9105',
#  'V9106',
#  'V9107',
#  'V9108',
#  'V1091',
#  'V1092',
#  'V9910',
#  'V9911',
#  'V9112',
#  'V9113',
#  'V9114',
#  'V9115',
#  'V9116',
#  'V9117',
#  'V9118',
#  'V9119',
#  'V9120',
#  'V9121',
#  'V9921',
#  'V9122',
#  'V9123',
#  'V9124',
#  'V1251',
#  'V1252',
#  'V1254',
#  'V1255',
#  'V1257',
#  'V1258',
#  'V1260',
#  'V1261',
#  'V1263',
#  'V1264',
#  'V1266',
#  'V1267',
#  'V1269',
#  'V1270',
#  'V1272',
#  'V1273',
#  'V9126',
#  'V1101',
#  'V1141',
#  'V1142',
#  'V1151',
#  'V1152',
#  'V1153',
#  'V1154',
#  'V1161',
#  'V1162',
#  'V1163',
#  'V1164',
#  'V1107',
#  'V1181',
#  'V1182',
#  'V1109',
#  'V1110',
#  'V1111',
#  'V1112',
#  'V1113',
#  'V1114',
#  'V1115',
#  'V4801',
#  'V4802',
#  'V4803',
#  'V4704',
#  'V4805',
#  'V4706',
#  'V4707',
#  'V4808',
#  'V4809',
#  'V4810',
#  'V4711',
#  'V4812',
#  'V4713',
#  'V4814',
#  'V4715',
#  'V4816',
#  'V4817',
#  'V4718',
#  'V4719',
#  'V4720',
#  'V4721',
#  'V4722',
#  'V4723',
#  'V4724',
#  'V4727',
#  'V4728',
#  'V4729',
#  'V4732',
#  'V4735',
#  'V4838',
#  'V6502',
#  'V4741',
#  'V4742',
#  'V4743',
#  'V4745',
#  'V4746',
#  'V4747',
#  'V4748',
#  'V4749',
#  'V4750',
#  'V9993']

# %%
PES2015.columns = new_columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c5feb1fbe8cd> in <module>()
# ----> 1 PES2015.columns = new_columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
#    3072             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    3073                              'new values have %d elements' %
# -> 3074                              (old_len, new_len))
#    3075
#    3076         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 328 elements, new values have 358 elements

# %%
PES2015.head()
